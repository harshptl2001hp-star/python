# %%
# Indexing and slicing
import numpy
arr = numpy.random.randint(1, 50, size=(6,4))

# %%
arr
# Out:
# array([[22, 15,  1, 35],
#        [13, 48,  1, 40],
#        [ 4, 45,  6, 37],
#        [24, 48, 39,  5],
#        [11, 13,  7, 13],
#        [24, 35, 15, 11]], dtype=int32)

# %%
arr[0,2]
# Out:
# np.int32(1)

# %%
arr
# Out:
# array([[22, 15,  1, 35],
#        [13, 48,  1, 40],
#        [ 4, 45,  6, 37],
#        [24, 48, 39,  5],
#        [11, 13,  7, 13],
#        [24, 35, 15, 11]], dtype=int32)

# %%
arr[0,2]
# Out:
# np.int32(1)

# %%
arr[0:5]
# Out:
# array([[22, 15,  1, 35],
#        [13, 48,  1, 40],
#        [ 4, 45,  6, 37],
#        [24, 48, 39,  5],
#        [11, 13,  7, 13]], dtype=int32)

# %%
import array


arr[2, 2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 import array
#       2
#       3
# ----> 4 array[2,2]
#
# TypeError: 'module' object is not subscriptable
